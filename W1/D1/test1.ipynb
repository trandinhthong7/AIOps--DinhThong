# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("numenta NAB master data-realKnownCause/ec2_request_latency_system_failure.csv")
df.head()
# Out:
#              timestamp   value
# 0  2014-03-07 03:41:00  45.868
# 1  2014-03-07 03:46:00  47.606
# 2  2014-03-07 03:51:00  42.580
# 3  2014-03-07 03:56:00  46.030
# 4  2014-03-07 04:01:00  44.992

# %%
skewness = stats.skew(df['value'])
print("Skewness:", skewness)
# Out:
# Skewness: 3.061855073144644
